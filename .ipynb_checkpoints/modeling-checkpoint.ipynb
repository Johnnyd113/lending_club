# %% [markdown]
# In this notebook create a baseline model. LightGBM is used because its generally as accurate as xgboost, but runs much faster. LightGBM will also generally perform better than a linear model, KNN, SVM, or other tree based methods. Only cleaning/feature eng will be done to fit data into format LighGBM can use.

# %%
import warnings
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
from pathlib import Path
# %matplotlib inline
pd.set_option('display.max_columns', 50)
warnings.filterwarnings('ignore')
# Out:
# /Users/johndimarco/anaconda3/envs/lending_club/lib/python3.7/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
train_df = pd.read_pickle('clean_data/train_df.pkl').iloc[:,2:] # first two columns are id info
val_df = pd.read_pickle('clean_data/val_df.pkl').iloc[:,2:]
#test_df = pd.read_pickle('clean_data/test_df.pkl')

# %%
train_df.head()
# Out:
#         loan_amnt  term  int_rate  installment grade sub_grade emp_length  \
# 128412    12000.0    36      7.62       373.94     A        A3    3 years
# 128413    27050.0    36     10.99       885.46     B        B2  10+ years
# 128414    12000.0    36     11.99       398.52     B        B3  10+ years
# 128415    28000.0    36      7.62       872.52     A        A3    5 years
# 128417    12000.0    36     10.99       392.81     B        B2    4 years
#
#        home_ownership  annual_inc verification_status  \
# 128412       MORTGAGE     96500.0        Not Verified
# 128413            OWN     55000.0            Verified
# 128414       MORTGAGE    130000.0     Source Verified
# 128415       MORTGAGE    325000.0     Source Verified
# 128417           RENT     60000.0        Not Verified
#
#                                                      desc             purpose  \
# 128412    Borrower added on 12/31/13 > Bought a new ho...  debt_consolidation
# 128413    Borrower added on 12/31/13 > Combining high ...  debt_consolidation
# 128414                                                NaN  debt_consolidation
# 128415                                                NaN  debt_consolidation
# 128417    Borrower added on 12/31/13 > I would like to...  debt_consolidation
#
#        zip_code addr_state initial_list_status  \
# 128412    782xx         TX                   f
# 128413    481xx         MI                   w
# 128414    809xx         CO                   f
# 128415    945xx         CA                   w
# 128417    281xx         NC                   f
#
#                                   emp_title  acc_now_delinq  \
# 128412                     Systems Engineer             0.0
# 128413  Team Leadern Customer Ops & Systems             0.0
# 128414                                  LTC             0.0
# 128415                   Area Sales Manager             0.0
# 128417                      Project Manager             0.0
#
#         acc_open_past_24mths  bc_open_to_buy  percent_bc_gt_75  bc_util  \
# 128412                   4.0          2441.0             100.0     83.5
# 128413                   3.0         16473.0              25.0     53.9
# 128414                   4.0          3567.0               1.0     93.0
# 128415                   6.0         13901.0              16.7     67.1
# 128417                   8.0         15216.0               0.0     15.9
#
#           dti  delinq_2yrs  delinq_amnt  earliest_cr_line  ...  max_bal_bc  \
# 128412  12.61          0.0          0.0               123  ...         NaN
# 128413  22.87          0.0          0.0               326  ...         NaN
# 128414  13.03          0.0          0.0               192  ...         NaN
# 128415  18.55          0.0          0.0               228  ...         NaN
# 128417   4.62          0.0          0.0                48  ...         NaN
#
#         all_util  inq_fi  total_cu_tl  inq_last_12m  sec_app_fico_range_low  \
# 128412       NaN     NaN          NaN           NaN                     NaN
# 128413       NaN     NaN          NaN           NaN                     NaN
# 128414       NaN     NaN          NaN           NaN                     NaN
# 128415       NaN     NaN          NaN           NaN                     NaN
# 128417       NaN     NaN          NaN           NaN                     NaN
#
#         sec_app_fico_range_high  sec_app_earliest_cr_line  \
# 128412                      NaN                       NaN
# 128413                      NaN                       NaN
# 128414                      NaN                       NaN
# 128415                      NaN                       NaN
# 128417                      NaN                       NaN
#
#         sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 128412                     NaN               NaN               NaN
# 128413                     NaN               NaN               NaN
# 128414                     NaN               NaN               NaN
# 128415                     NaN               NaN               NaN
# 128417                     NaN               NaN               NaN
#
#         sec_app_revol_util  sec_app_num_rev_accts  \
# 128412                 NaN                    NaN
# 128413                 NaN                    NaN
# 128414                 NaN                    NaN
# 128415                 NaN                    NaN
# 128417                 NaN                    NaN
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 128412                               NaN                                 NaN
# 128413                               NaN                                 NaN
# 128414                               NaN                                 NaN
# 128415                               NaN                                 NaN
# 128417                               NaN                                 NaN
#
#         sec_app_mths_since_last_major_derog  revol_bal_joint  open_act_il  \
# 128412                                  NaN              NaN          NaN
# 128413                                  NaN              NaN          NaN
# 128414                                  NaN              NaN          NaN
# 128415                                  NaN              NaN          NaN
# 128417                                  NaN              NaN          NaN
#
#         sec_app_open_act_il    issue_d  loan_status   total_pymnt  \
# 128412                  NaN 2013-12-01   Fully Paid  13397.539998
# 128413                  NaN 2013-12-01   Fully Paid  31752.530000
# 128414                  NaN 2013-12-01   Fully Paid  14346.479050
# 128415                  NaN 2013-12-01   Fully Paid  29150.980000
# 128417                  NaN 2013-12-01   Fully Paid  13988.609996
#
#         total_rec_int  total_rec_late_fee  total_rec_prncp
# 128412        1397.54                 0.0          12000.0
# 128413        4702.53                 0.0          27050.0
# 128414        2346.48                 0.0          12000.0
# 128415        1150.98                 0.0          28000.0
# 128417        1988.61                 0.0          12000.0
#
# [5 rows x 109 columns]

# %% [markdown]
# Create list of features by removing loan performace info

# %%
to_drop = ['issue_d','desc','loan_status', 'total_pymnt','total_rec_int','total_rec_late_fee','total_rec_prncp']
x_cols = [x for x in list(train_df.columns) if x not in to_drop]

# %% [markdown]
# Check which cols are strings

# %%
for col in x_cols:
    if train_df[col].dtype == object:
        print(col)
# Out:
# grade
# sub_grade
# emp_length
# home_ownership
# verification_status
# purpose
# zip_code
# addr_state
# initial_list_status
# emp_title
# application_type
# verification_status_joint
# sec_app_earliest_cr_line

# %% [markdown]
# To encode the categorical/str columns to numbers:
# 1. Create a dictionary with encoding info for each column
# 2. For each column, with the training data create a dict mapping each category to an int
# 3. Apply the categorical mapping from str to ints on the train and val data
#
# Sklearn label encoder was not used because it has issues if there are values in the val set we are mapping that were not seen in the train encodings. We do not want to fit a label encoder on both train and val data because we are simulating training on historical data to validate against unseen data.

# %%
cat_encs = {}

for col in x_cols:
    if train_df[col].dtype == object:
        cat_encs[col] = dict(zip(train_df[col].unique(), range(len(train_df[col].unique()))))
        
for col in cat_encs.keys():
    val_df[col] = val_df[col].map(cat_encs[col], na_action='UNK')
    train_df[col] = train_df[col].map(cat_encs[col], na_action='UNK')

# %% [markdown]
# cat_encs is a dictionary of features. each feature is a dictionary with its categorical mapping

# %%
cat_encs['purpose']
# Out:
# {'debt_consolidation': 0,
#  'other': 1,
#  'home_improvement': 2,
#  'credit_card': 3,
#  'small_business': 4,
#  'house': 5,
#  'moving': 6,
#  'medical': 7,
#  'car': 8,
#  'major_purchase': 9,
#  'vacation': 10,
#  'renewable_energy': 11,
#  'wedding': 12,
#  'educational': 13}

# %%
# split the data from full dfs, to x,y
x_train = train_df[x_cols]
y_train = train_df['loan_status']

x_val = val_df[x_cols]
y_val = val_df['loan_status']

# Label encode target column
y_train = y_train.map({'Fully Paid': 0, 'Charged Off': 1})
y_val = y_val.map({'Fully Paid': 0, 'Charged Off': 1})

# %%
# lgbm with default params
params = {'num_leaves': 32,
          'metric': 'auc',}

train_data = lgb.Dataset(x_train,
                         label=y_train)

val_data = lgb.Dataset(x_val,
                       label=y_val)

model = lgb.train(params,
                  train_data,
                  num_boost_round=1000,
                  valid_sets = [train_data, val_data],
                  verbose_eval=100,
                  early_stopping_rounds = 100)
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.732372	valid_1's auc: 0.688922
# [200]	training's auc: 0.767839	valid_1's auc: 0.685815
# Early stopping, best iteration is:
# [118]	training's auc: 0.740094	valid_1's auc: 0.689069

# %%
# view most important features
fi = list(zip(model.feature_name(),model.feature_importance(importance_type='gain')))
fi.sort(key = lambda tup: tup[1], reverse=True)
fi[:10]
# Out:
# [('int_rate', 2477.808713078499),
#  ('annual_inc', 998.7596771717072),
#  ('grade', 721.8495355844498),
#  ('acc_open_past_24mths', 401.91810071468353),
#  ('emp_title', 355.08557373285294),
#  ('dti', 345.4366352558136),
#  ('installment', 306.18234461545944),
#  ('mths_since_recent_bc', 279.92888551950455),
#  ('loan_amnt', 272.6489664912224),
#  ('total_bc_limit', 256.12167739868164)]

# %% [markdown]
# Next view hypothetical returns for different default thresholds. We are most interested in optimizing investment returns

# %%
preds = model.predict(x_val)

# %%
val_df['prediction'] = preds

# %%
val_df.head()
# Out:
#         loan_amnt  term  int_rate  installment  grade  sub_grade  emp_length  \
# 316593    10400.0    36      6.99       321.08      0          0           8
# 316595     9600.0    36     13.66       326.53      2          3           1
# 316596     7650.0    36     13.66       260.20      2          3           9
# 316599    17000.0    36     13.66       578.22      2          3           1
# 316600    23325.0    36     14.31       800.71      2         13           1
#
#         home_ownership  annual_inc  verification_status desc  purpose  \
# 316593             0.0     58000.0                    0  NaN        3
# 316595             2.0     69000.0                    2  NaN        0
# 316596             2.0     50000.0                    2  NaN        0
# 316599             0.0     75000.0                    1  NaN        0
# 316600             2.0     72000.0                    2  NaN        3
#
#         zip_code  addr_state  initial_list_status  emp_title  acc_now_delinq  \
# 316593     493.0           3                    1        NaN             0.0
# 316595     378.0          12                    0     2293.0             0.0
# 316596     132.0          27                    0     8697.0             0.0
# 316599     305.0           5                    0     2110.0             0.0
# 316600     206.0          21                    0        5.0             0.0
#
#         acc_open_past_24mths  bc_open_to_buy  percent_bc_gt_75  bc_util  \
# 316593                   7.0          7599.0              14.3     41.5
# 316595                   8.0          6494.0              60.0     69.2
# 316596                   6.0           332.0             100.0     93.2
# 316599                   2.0            71.0             100.0     98.2
# 316600                   6.0          3977.0              66.7     89.0
#
#           dti  delinq_2yrs  delinq_amnt  earliest_cr_line  ...  all_util  \
# 316593  14.92          0.0          0.0               302  ...       NaN
# 316595  25.81          0.0          0.0               264  ...       NaN
# 316596  34.81          0.0          0.0               148  ...       NaN
# 316599  23.63          0.0          0.0               166  ...       NaN
# 316600  27.03          1.0          0.0               194  ...       NaN
#
#         inq_fi  total_cu_tl  inq_last_12m  sec_app_fico_range_low  \
# 316593     NaN          NaN           NaN                     NaN
# 316595     NaN          NaN           NaN                     NaN
# 316596     NaN          NaN           NaN                     NaN
# 316599     NaN          NaN           NaN                     NaN
# 316600     NaN          NaN           NaN                     NaN
#
#         sec_app_fico_range_high  sec_app_earliest_cr_line  \
# 316593                      NaN                         0
# 316595                      NaN                         0
# 316596                      NaN                         0
# 316599                      NaN                         0
# 316600                      NaN                         0
#
#         sec_app_inq_last_6mths  sec_app_mort_acc  sec_app_open_acc  \
# 316593                     NaN               NaN               NaN
# 316595                     NaN               NaN               NaN
# 316596                     NaN               NaN               NaN
# 316599                     NaN               NaN               NaN
# 316600                     NaN               NaN               NaN
#
#         sec_app_revol_util  sec_app_num_rev_accts  \
# 316593                 NaN                    NaN
# 316595                 NaN                    NaN
# 316596                 NaN                    NaN
# 316599                 NaN                    NaN
# 316600                 NaN                    NaN
#
#         sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 316593                               NaN                                 NaN
# 316595                               NaN                                 NaN
# 316596                               NaN                                 NaN
# 316599                               NaN                                 NaN
# 316600                               NaN                                 NaN
#
#         sec_app_mths_since_last_major_derog  revol_bal_joint  open_act_il  \
# 316593                                  NaN              NaN          NaN
# 316595                                  NaN              NaN          NaN
# 316596                                  NaN              NaN          NaN
# 316599                                  NaN              NaN          NaN
# 316600                                  NaN              NaN          NaN
#
#         sec_app_open_act_il    issue_d  loan_status   total_pymnt  \
# 316593                  NaN 2014-12-01  Charged Off   6611.690000
# 316595                  NaN 2014-12-01   Fully Paid   9973.430000
# 316596                  NaN 2014-12-01  Charged Off   2281.980000
# 316599                  NaN 2014-12-01   Fully Paid  19562.310001
# 316600                  NaN 2014-12-01  Charged Off  13907.790000
#
#         total_rec_int  total_rec_late_fee  total_rec_prncp  prediction
# 316593         872.67                 0.0          5217.75    0.058485
# 316595         373.43                 0.0          9600.00    0.173290
# 316596         339.61                 0.0           704.38    0.167986
# 316599        2562.31                 0.0         17000.00    0.118773
# 316600        3061.64                 0.0          7301.23    0.156541
#
# [5 rows x 110 columns]

# %%
val_df['paid_issued'] = val_df['total_pymnt'] - val_df['loan_amnt']
val_df['pct_earned'] = val_df['paid_issued']/val_df['loan_amnt']

# %%
thresholds = [x/100 for x in range(0,100)]

# %%
# creates a list of our hypothetical investment returns for different loan prediction thresholds
returns = []
for thresh in thresholds:
    total_paid = val_df.loc[val_df['prediction']<=thresh, 'total_pymnt'].sum()
    total_issued = val_df.loc[val_df['prediction']<=thresh, 'loan_amnt'].sum()
    returns.append(total_paid/total_issued)

# %%
total_paid = val_df['total_pymnt'].sum()
total_issued = val_df['loan_amnt'].sum()
val_df_av_returns = total_paid/total_issued
val_df_av_returns
# Out:
# 1.0815881506496374

# %%
# plot returns at different thresholds vs total val_df returns
plt.plot(returns)
plt.plot([val_df_av_returns]*len(thresholds))

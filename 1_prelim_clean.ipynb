# %% [markdown]
# This notebook is a quick cleaning of the data just to get it usable for our baseline ML models. This is quick and dirty cleaning with further refinements (feature eng, cat encoding, etc) to be done later. Different models will require different cleaning so this mostly just combines all the seperate csv files and establishes train-val, and holdout_test set

# %%
import os, warnings, gc, requests, json, re
from requests.auth import HTTPDigestAuth
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

# %%
data_path = 'data/' # replace with name of your data file if different
key = '' # put your api key here
acc_id = '' # put your account id here

# %% [markdown]
# The cleaning function does some very simple cleaning like converting interest rates from strings to floats.

# %%
def cleaning(df):
            
    # drop non_loan columns
    index = df[df['loan_amnt'].isnull()].index
    df.drop(index=index, inplace=True)
    
    # convert % rate from str to float
    df['int_rate'] = df['int_rate'].str[:-1].astype(float)
    df['revol_util'] = df['revol_util'].str[:-1].astype(float)
    
    # convert term from str to int
    df['term'] = df['term'].str.strip().str[:2].astype(int)
    
    # drop weird old columns
    index = (df[(df['loan_status'] == 'Does not meet the credit policy. Status:Charged Off')
            |(df['loan_status'] == 'Does not meet the credit policy. Status:Fully Paid')]).index
    df.drop(index=index, inplace=True)
    
    # convert dates to useable formats
    df['earliest_cr_line'] = pd.to_datetime(df['earliest_cr_line'], format='%b-%Y')
    df['issue_d'] = pd.to_datetime(df['issue_d'], format='%b-%Y')
    
    # convert earliest cr_line from date to months since loan request
    df['earliest_cr_line'] = ((df['issue_d'] - df['earliest_cr_line']) / np.timedelta64(1, 'M')).astype(int)
    
    return df

# %% [markdown]
# The historical data is split into different csv files. The get data function will clean each one, then combine them all into one dataframe.

# %%
def get_data(approved_files, data_path):
    df = pd.DataFrame()
    for file in approved_files:
        print(f'reading in {file}')
        temp_df = pd.read_csv(data_path+file,header=1)
        temp_df = cleaning(temp_df)
        df = pd.concat([df,temp_df],ignore_index=True)
    del temp_df
    return df

# %% [markdown]
# My data folder also contains info on rejected loans. Bc of this, make a list of files containing only the csv files containing approved and issued loans

# %%
files = os.listdir(data_path)
# only files with approved loans start with 'L'
approved_files = [f for f in files if f[0]=='L']

# %% [markdown]
# Clean and combine all historical loan files into one.

# %%
df = get_data(approved_files, data_path)
# Out:
# reading in LoanStats_securev1_2018Q4.csv
# reading in LoanStats3b_securev1.csv
# reading in LoanStats3c_securev1.csv
# reading in LoanStats3d_securev1.csv
# reading in LoanStats_securev1_2018Q2.csv
# reading in LoanStats_securev1_2018Q3.csv
# reading in LoanStats_securev1_2018Q1.csv
# reading in LoanStats_securev1_2019Q1.csv
# reading in LoanStats_securev1_2019Q2.csv
# reading in LoanStats_securev1_2019Q3.csv
# reading in LoanStats_securev1_2017Q1.csv
# reading in LoanStats_securev1_2017Q2.csv
# reading in LoanStats_securev1_2017Q3.csv
# reading in LoanStats_securev1_2017Q4.csv
# reading in LoanStats_securev1_2016Q2.csv
# reading in LoanStats3a_securev1.csv
# reading in LoanStats_securev1_2016Q3.csv
# reading in LoanStats_securev1_2016Q1.csv
# reading in LoanStats_securev1_2016Q4.csv

# %%
df.head()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  145073496        NaN     6000.0       6000.0           6000.0    36
# 1  145548792        NaN    24000.0      24000.0          24000.0    36
# 2  145565309        NaN    30000.0      30000.0          30000.0    36
# 3  145614543        NaN     8000.0       8000.0           8000.0    36
# 4  145619975        NaN    22400.0      22400.0          22400.0    60
#
#    int_rate  installment grade sub_grade                emp_title emp_length  \
# 0     14.47       206.44     C        C2                  Manager  10+ years
# 1     10.33       778.14     B        B1      Maintenance Manager  10+ years
# 2     15.02      1040.26     C        C3             Firefighter   10+ years
# 3     12.98       269.48     B        B5               Controller    4 years
# 4     16.14       546.40     C        C4  Paramedic/ Fire Fighter  10+ years
#
#   home_ownership  annual_inc verification_status    issue_d  loan_status  \
# 0           RENT     55000.0            Verified 2018-12-01  Charged Off
# 1       MORTGAGE    100000.0        Not Verified 2018-12-01      Current
# 2           RENT     90000.0            Verified 2018-12-01   Fully Paid
# 3       MORTGAGE     95000.0     Source Verified 2018-12-01      Current
# 4            OWN     56000.0     Source Verified 2018-12-01      Current
#
#   pymnt_plan                                                url desc  \
# 0          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 3          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 4          n  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#               purpose                    title zip_code addr_state    dti  \
# 0         credit_card  Credit card refinancing    104xx         NY  10.65
# 1  debt_consolidation       Debt consolidation    606xx         IL  19.14
# 2  debt_consolidation       Debt consolidation    681xx         NE  22.23
# 3         credit_card  Credit card refinancing    480xx         MI   9.44
# 4         credit_card  Credit card refinancing    234xx         VA  18.47
#
#    ...  sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0  ...                               NaN                                 NaN
# 1  ...                               NaN                                 NaN
# 2  ...                               NaN                                 NaN
# 3  ...                               NaN                                 NaN
# 4  ...                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog  hardship_flag  hardship_type  \
# 0                                  NaN              N            NaN
# 1                                  NaN              N            NaN
# 2                                  NaN              N            NaN
# 3                                  NaN              N            NaN
# 4                                  NaN              N            NaN
#
#    hardship_reason  hardship_status  deferral_term  hardship_amount  \
# 0              NaN              NaN            NaN              NaN
# 1              NaN              NaN            NaN              NaN
# 2              NaN              NaN            NaN              NaN
# 3              NaN              NaN            NaN              NaN
# 4              NaN              NaN            NaN              NaN
#
#    hardship_start_date  hardship_end_date  payment_plan_start_date  \
# 0                  NaN                NaN                      NaN
# 1                  NaN                NaN                      NaN
# 2                  NaN                NaN                      NaN
# 3                  NaN                NaN                      NaN
# 4                  NaN                NaN                      NaN
#
#   hardship_length  hardship_dpd  hardship_loan_status  \
# 0             NaN           NaN                   NaN
# 1             NaN           NaN                   NaN
# 2             NaN           NaN                   NaN
# 3             NaN           NaN                   NaN
# 4             NaN           NaN                   NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount  debt_settlement_flag  \
# 0                           NaN                     Y
# 1                           NaN                     N
# 2                           NaN                     N
# 3                           NaN                     N
# 4                           NaN                     N
#
#    debt_settlement_flag_date  settlement_status  settlement_date  \
# 0                   Oct-2019             ACTIVE         Oct-2019
# 1                        NaN                NaN              NaN
# 2                        NaN                NaN              NaN
# 3                        NaN                NaN              NaN
# 4                        NaN                NaN              NaN
#
#   settlement_amount  settlement_percentage settlement_term
# 0            3479.0                  60.01            24.0
# 1               NaN                    NaN             NaN
# 2               NaN                    NaN             NaN
# 3               NaN                    NaN             NaN
# 4               NaN                    NaN             NaN
#
# [5 rows x 150 columns]

# %%
df.shape
# Out:
# (2647537, 150)

# %%
# to view all column names
#list(df.columns)

# %% [markdown]
# The dataframe currently holds information not available at the time of investment.

# %% [markdown]
# Enter your LC account info to preview the currently listed loans. From the currently available loans create a list of all available features. These are the features we know we can use in our ML models. Then try to match these features to the ones available in the Lending Club historical data.

# %%
api_key =  {'Authorization': key} 
acc_id = acc_id 

# get loan listings data
loans = 'https://api.lendingclub.com/api/investor/v1/loans/listing'
res = requests.get(loans, headers=api_key)
data = json.loads(res.text)

# grabs the available features
avail_cols = list(data['loans'][0].keys())

# %%
# to view columns from the listings api
#avail_cols

# %% [markdown]
# Feature names from the api differ from the historical data. Since it's mostly slight formatting differences regex functions will be used to match column names. A dictionary is created to map other feature names from the api to the historical data. Some of the features mapped in the dictionary could also be matched using regex

# %%
to_map = {'secAppCollections12MthsExMed': 'sec_app_collections_12_mths_ex_med',
          'secAppInqLast6Mths': 'sec_app_inq_last_6mths',
          'numAcctsEver120Ppd': 'num_accts_ever_120_pd',
          'inqLast6Mths': 'inq_last_6mths',
          'numTl120dpd2m': 'num_tl_120dpd_2m',
          'numTl30dpd': 'num_tl_30dpd',
          'numTl90gDpd24m': 'num_tl_90g_dpd_24m',
          'numTlOpPast12m': 'num_tl_op_past_12m',
          'collections12MthsExMed': 'collections_12_mths_ex_med',
          'isIncV': 'verification_status',
          'isIncVJoint': 'verification_status_joint',
          'openIl12m': 'open_il_12m',
          'openIl24m': 'open_il_24m',
          'openRv12m': 'open_rv_12m',
          'openRv24m': 'open_rv_24m',
          'secAppChargeoffWithin12Mths': 'sec_app_chargeoff_within_12_mths',
          'addrZip': 'zip_code',
          'accOpenPast24Mths': 'acc_open_past_24mths',
          'chargeoffWithin12Mths': 'chargeoff_within_12_mths',
          'inqLast12m': 'inq_last_12m',
          'delinq2Yrs': 'delinq_2yrs',
          'percentBcGt75': 'percent_bc_gt_75',
          'loanAmount': 'loan_amnt',
          'iLUtil': 'il_util',          
         }

# cols w info regarding loan performace from LC dataset
# this will get stored with the data used for modeling so we can see returns on investment later
cols_of_interest = ['issue_d','loan_status','total_pymnt', 'total_rec_int',
                    'total_rec_late_fee','total_rec_prncp', 'recoveries',
                    'collection_recovery_fee', 'last_pymnt_d']
                    

# cols dropped from the listed loans features (these features are not in historical data)
to_drop = ['reviewStatus', 'housingPayment', 'creditPullD', 'ilsExpD', 'mtgPayment', 'expD', 'acceptD',
          'investorCount','serviceFeeRate', 'disbursementMethod', 'listD', 'expDefaultRate',
          'reviewStatusD','fundedAmount']

# %% [markdown]
# The next block calls the lendingclub api to get a list of available loans. From this we get the available features to use for our models. You can use your api key and investor id.

# %%
# performs feature matching between features from api call and features from dataset
# some features were easy to match with regex but for others is was quick to manually write mapping
# this can probably be clean up further
api_cols = []
for col in avail_cols:
    if col in list(to_map.keys()):
        new_col = to_map[col]
        api_cols.append(new_col)
        continue
    if col in to_drop:
        continue
    new_col = re.sub(r'([A-Z])', r'_\1', col).lower()
    new_col = re.sub(r'([0-9])+', r'_\1', new_col).lower()
    api_cols.append(new_col)

# %%
api_cols[:10]
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_length',
#  'home_ownership']

# %%
len(api_cols)
# Out:
# 105

# %% [markdown]
# api_cols is a list of usable features from the api call listed the feature names in the historical data. Now reassign the dataframe into a df with only the features we want.

# %%
df = df[api_cols+cols_of_interest]

# %%
df.head()
# Out:
#           id  member_id  loan_amnt  term  int_rate  installment grade  \
# 0  145073496        NaN     6000.0    36     14.47       206.44     C
# 1  145548792        NaN    24000.0    36     10.33       778.14     B
# 2  145565309        NaN    30000.0    36     15.02      1040.26     C
# 3  145614543        NaN     8000.0    36     12.98       269.48     B
# 4  145619975        NaN    22400.0    60     16.14       546.40     C
#
#   sub_grade emp_length home_ownership  annual_inc verification_status desc  \
# 0        C2  10+ years           RENT     55000.0            Verified  NaN
# 1        B1  10+ years       MORTGAGE    100000.0        Not Verified  NaN
# 2        C3  10+ years           RENT     90000.0            Verified  NaN
# 3        B5    4 years       MORTGAGE     95000.0     Source Verified  NaN
# 4        C4  10+ years            OWN     56000.0     Source Verified  NaN
#
#               purpose zip_code addr_state initial_list_status  \
# 0         credit_card    104xx         NY                   w
# 1  debt_consolidation    606xx         IL                   w
# 2  debt_consolidation    681xx         NE                   w
# 3         credit_card    480xx         MI                   w
# 4         credit_card    234xx         VA                   w
#
#                  emp_title  acc_now_delinq  acc_open_past_24mths  \
# 0                  Manager             0.0                   2.0
# 1      Maintenance Manager             0.0                   9.0
# 2             Firefighter              0.0                   5.0
# 3               Controller             0.0                  10.0
# 4  Paramedic/ Fire Fighter             0.0                   2.0
#
#    bc_open_to_buy  percent_bc_gt_75  bc_util    dti  delinq_2yrs  ...  \
# 0           344.0             100.0     92.0  10.65          0.0  ...
# 1         17353.0              16.7     33.0  19.14          0.0  ...
# 2         22030.0              50.0     47.0  22.23          0.0  ...
# 3         22866.0              20.0     33.3   9.44          0.0  ...
# 4         15054.0              25.0     46.6  18.47          0.0  ...
#
#    total_cu_tl  inq_last_12m  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0          0.0           2.0                     NaN                      NaN
# 1          0.0           8.0                     NaN                      NaN
# 2          2.0           1.0                     NaN                      NaN
# 3          0.0           7.0                     NaN                      NaN
# 4          0.0           4.0                     NaN                      NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                       NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
# 2                       NaN                     NaN               NaN
# 3                       NaN                     NaN               NaN
# 4                       NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_num_rev_accts  \
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2               NaN                 NaN                    NaN
# 3               NaN                 NaN                    NaN
# 4               NaN                 NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog  revol_bal_joint  open_act_il  \
# 0                                  NaN              NaN          2.0
# 1                                  NaN              NaN          5.0
# 2                                  NaN              NaN          2.0
# 3                                  NaN              NaN          1.0
# 4                                  NaN              NaN          3.0
#
#    sec_app_open_act_il    issue_d  loan_status   total_pymnt  total_rec_int  \
# 0                  NaN 2018-12-01  Charged Off   1106.520000         272.38
# 1                  NaN 2018-12-01      Current   9317.020000        2124.32
# 2                  NaN 2018-12-01   Fully Paid  30883.673712         883.67
# 3                  NaN 2018-12-01      Current   6855.630000         562.97
# 4                  NaN 2018-12-01      Current   6526.670000        3357.58
#
#    total_rec_late_fee  total_rec_prncp  recoveries  collection_recovery_fee  \
# 0                 0.0           546.14       288.0                    51.84
# 1                 0.0          7192.70         0.0                     0.00
# 2                 0.0         30000.00         0.0                     0.00
# 3                 0.0          6292.66         0.0                     0.00
# 4                 0.0          3169.09         0.0                     0.00
#
#    last_pymnt_d
# 0      Apr-2019
# 1      Dec-2019
# 2      Feb-2019
# 3      Dec-2019
# 4      Dec-2019
#
# [5 rows x 114 columns]

# %%
# save data
df.to_pickle('data/prelim-all.pkl')

# %% [markdown]
# Next create train/val/test splits. Since only historical data will be avaible when choosing which loans to invest in, I chose to split the data by date. I only use 36m term loans instead of both 36 and 60m because I do not want my money locked in an investment for 5 years.
#
# Most recent data is Q3 2019 so 36m loans from Q3 2016 and earlier should be fully paid off or confirmed default by now. This most recent loan data from Q4 2015- Q3 2016 will be used as the test set.
#
# Train and Validation sets will have loans from Q3 2015 and earlier

# %%
df = pd.read_pickle('data/prelim-all.pkl')

# %% [markdown]
# Chose to restric to 36 month loans because so we have full payment info on more recent data. The other loan term is 5 years and would limit the time periods available for a train/val/holdout data split.

# %%
# restrict to 36m loans
df = df[df['term']==36]

# %%
df.shape
# Out:
# (1871233, 114)

# %% [markdown]
# Next a few features are added to later calculate annualized returns.

# %%
# how long until the loan was paid off/reached default status
df['loan_length'] = (pd.to_datetime(df['last_pymnt_d'])-df['issue_d']).dt.days

# loans that did not recieve any payments had NA values
# by adding 30 days it provides a timeframe to calculate returns
# NA values messed up the calculation
df['loan_length'] = df['loan_length'].fillna(30)

# loans that were paid off in the same month had a loan length of 0
# loan length of zero pushed returns to infinity
# loans also take some time to originate after initial investment
# adding 30 days creates cleaner and more realistic return calculations
df.loc[df['loan_length']==0, 'loan_length'] = 30

# recoveries are not factored into the last_pyment_d feature
# without this feature a loan can make the first payment, then default and make partial recovry pymnt
# and return on investment would be above 100%
# adding a year for the recovery peroid is also fairly realistic
df.loc[df['recoveries']>0, 'loan_length'] =df.loc[df['recoveries']>0, 'loan_length']+365

# standard annualized return formula
df['returns'] = (df['total_pymnt']/df['loan_amnt'])**(365/(df['loan_length'])) - 1

# %%
df.sort_values('returns').head()
# Out:
#                 id  member_id  loan_amnt  term  int_rate  installment grade  \
# 1597052  159096586        NaN    10000.0    36      8.81       317.12     A
# 1382894  148033283        NaN     7000.0    36      6.46       214.42     A
# 1647181  156170616        NaN    18900.0    36     25.00       751.47     D
# 1587217  159587785        NaN     6000.0    36     12.40       200.44     B
# 1475127  153519765        NaN     7000.0    36     10.33       226.96     B
#
#         sub_grade emp_length home_ownership  annual_inc verification_status  \
# 1597052        A5    2 years           RENT     46000.0        Not Verified
# 1382894        A1   < 1 year       MORTGAGE    205987.0        Not Verified
# 1647181        D4    9 years           RENT     45000.0            Verified
# 1587217        B4  10+ years       MORTGAGE     60000.0     Source Verified
# 1475127        B1        NaN            OWN     52000.0        Not Verified
#
#         desc             purpose zip_code addr_state initial_list_status  \
# 1597052  NaN         credit_card    752xx         TX                   w
# 1382894  NaN  debt_consolidation    834xx         ID                   w
# 1647181  NaN  debt_consolidation    010xx         MA                   w
# 1587217  NaN         credit_card    432xx         OH                   w
# 1475127  NaN  debt_consolidation    283xx         NC                   w
#
#                             emp_title  acc_now_delinq  acc_open_past_24mths  \
# 1597052                Branch Manager             0.0                   6.0
# 1382894  Public Awareness Coordinator             0.0                   1.0
# 1647181                        Server             0.0                   1.0
# 1587217             Computer Operator             0.0                   7.0
# 1475127                           NaN             0.0                   6.0
#
#          bc_open_to_buy  percent_bc_gt_75  bc_util    dti  delinq_2yrs  ...  \
# 1597052         15528.0               0.0     38.4  21.84          0.0  ...
# 1382894         13852.0              33.3     43.9   5.15          0.0  ...
# 1647181          2659.0              50.0     86.4  21.25          1.0  ...
# 1587217         13223.0              50.0     71.1  36.29          0.0  ...
# 1475127          6802.0               0.0     35.8  16.96          0.0  ...
#
#          sec_app_fico_range_low  sec_app_fico_range_high  \
# 1597052                     NaN                      NaN
# 1382894                     NaN                      NaN
# 1647181                     NaN                      NaN
# 1587217                     NaN                      NaN
# 1475127                     NaN                      NaN
#
#          sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 1597052                       NaN                     NaN               NaN
# 1382894                       NaN                     NaN               NaN
# 1647181                       NaN                     NaN               NaN
# 1587217                       NaN                     NaN               NaN
# 1475127                       NaN                     NaN               NaN
#
#          sec_app_open_acc  sec_app_revol_util  sec_app_num_rev_accts  \
# 1597052               NaN                 NaN                    NaN
# 1382894               NaN                 NaN                    NaN
# 1647181               NaN                 NaN                    NaN
# 1587217               NaN                 NaN                    NaN
# 1475127               NaN                 NaN                    NaN
#
#          sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 1597052                               NaN                                 NaN
# 1382894                               NaN                                 NaN
# 1647181                               NaN                                 NaN
# 1587217                               NaN                                 NaN
# 1475127                               NaN                                 NaN
#
#          sec_app_mths_since_last_major_derog  revol_bal_joint  open_act_il  \
# 1597052                                  NaN              NaN          8.0
# 1382894                                  NaN              NaN          0.0
# 1647181                                  NaN              NaN          2.0
# 1587217                                  NaN              NaN          2.0
# 1475127                                  NaN              NaN          2.0
#
#          sec_app_open_act_il    issue_d         loan_status  total_pymnt  \
# 1597052                  NaN 2019-09-01             Current       312.23
# 1382894                  NaN 2019-02-01         Charged Off         0.00
# 1647181                  NaN 2019-08-01  Late (31-120 days)         0.00
# 1587217                  NaN 2019-09-01             Current       196.31
# 1475127                  NaN 2019-06-01         Charged Off       222.94
#
#          total_rec_int  total_rec_late_fee  total_rec_prncp  recoveries  \
# 1597052          85.66                 0.0           226.57         0.0
# 1382894           0.00                 0.0             0.00         0.0
# 1647181           0.00                 0.0             0.00         0.0
# 1587217          57.87                 0.0           138.44         0.0
# 1475127          30.13                 0.0           192.81         0.0
#
#          collection_recovery_fee  last_pymnt_d  loan_length  returns
# 1597052                      0.0      Oct-2019         30.0     -1.0
# 1382894                      0.0           NaN         30.0     -1.0
# 1647181                      0.0           NaN         30.0     -1.0
# 1587217                      0.0      Oct-2019         30.0     -1.0
# 1475127                      0.0      Jul-2019         30.0     -1.0
#
# [5 rows x 116 columns]

# %%
df.sort_values('returns').tail()
# Out:
#                 id  member_id  loan_amnt  term  int_rate  installment grade  \
# 2016565  113730750        NaN    35000.0    36     30.79      1501.00     G
# 1397041  147450393        NaN     5000.0    36     27.27       204.86     E
# 1400045  147457038        NaN    15000.0    36     25.34       599.10     E
# 1956953  118567343        NaN     4200.0    36     29.69       177.59     F
# 2645214   90835542        NaN    10800.0    36     19.99       401.32     D
#
#         sub_grade emp_length home_ownership  annual_inc verification_status  \
# 2016565        G1    5 years           RENT    100000.0            Verified
# 1397041        E5    3 years           RENT     40500.0     Source Verified
# 1400045        E3   < 1 year           RENT     70000.0        Not Verified
# 1956953        F2        NaN           RENT     32496.0     Source Verified
# 2645214        D4    6 years            OWN     54559.0            Verified
#
#         desc             purpose zip_code addr_state initial_list_status  \
# 2016565  NaN  debt_consolidation    551xx         MN                   w
# 1397041  NaN  debt_consolidation    853xx         AZ                   w
# 1400045  NaN  debt_consolidation    951xx         CA                   w
# 1956953  NaN               other    852xx         AZ                   f
# 2645214  NaN    home_improvement    324xx         FL                   w
#
#                          emp_title  acc_now_delinq  acc_open_past_24mths  \
# 2016565          Owner / President             0.0                   6.0
# 1397041   Heavy Equipment Operator             0.0                   1.0
# 1400045  Consumer Loan Underwriter             0.0                   2.0
# 1956953                        NaN             0.0                   7.0
# 2645214                      Sraff             0.0                   1.0
#
#          bc_open_to_buy  percent_bc_gt_75  bc_util    dti  delinq_2yrs  ...  \
# 2016565          3601.0              50.0     57.6  18.83          0.0  ...
# 1397041           169.0              50.0     88.7  21.45          0.0  ...
# 1400045             0.0             100.0    101.2  22.90          0.0  ...
# 1956953          5657.0               0.0     21.4   7.98          0.0  ...
# 2645214          3000.0               0.0      0.0   0.00          0.0  ...
#
#          sec_app_fico_range_low  sec_app_fico_range_high  \
# 2016565                     NaN                      NaN
# 1397041                     NaN                      NaN
# 1400045                     NaN                      NaN
# 1956953                     NaN                      NaN
# 2645214                     NaN                      NaN
#
#          sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 2016565                       NaN                     NaN               NaN
# 1397041                       NaN                     NaN               NaN
# 1400045                       NaN                     NaN               NaN
# 1956953                       NaN                     NaN               NaN
# 2645214                       NaN                     NaN               NaN
#
#          sec_app_open_acc  sec_app_revol_util  sec_app_num_rev_accts  \
# 2016565               NaN                 NaN                    NaN
# 1397041               NaN                 NaN                    NaN
# 1400045               NaN                 NaN                    NaN
# 1956953               NaN                 NaN                    NaN
# 2645214               NaN                 NaN                    NaN
#
#          sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 2016565                               NaN                                 NaN
# 1397041                               NaN                                 NaN
# 1400045                               NaN                                 NaN
# 1956953                               NaN                                 NaN
# 2645214                               NaN                                 NaN
#
#          sec_app_mths_since_last_major_derog  revol_bal_joint  open_act_il  \
# 2016565                                  NaN              NaN          2.0
# 1397041                                  NaN              NaN          1.0
# 1400045                                  NaN              NaN          1.0
# 1956953                                  NaN              NaN          1.0
# 2645214                                  NaN              NaN          0.0
#
#          sec_app_open_act_il    issue_d  loan_status   total_pymnt  \
# 2016565                  NaN 2017-08-01   Fully Paid  36837.386580
# 1397041                  NaN 2019-02-01   Fully Paid   5248.242190
# 1400045                  NaN 2019-02-01   Fully Paid  15754.433017
# 1956953                  NaN 2017-09-01   Fully Paid   4430.433854
# 2645214                  NaN 2016-10-01  Charged Off  23439.240000
#
#          total_rec_int  total_rec_late_fee  total_rec_prncp  recoveries  \
# 2016565        1837.39                 0.0          35000.0        0.00
# 1397041         248.24                 0.0           5000.0        0.00
# 1400045         754.43                 0.0          15000.0        0.00
# 1956953         230.43                 0.0           4200.0        0.00
# 2645214           0.00                 0.0              0.0    23439.24
#
#          collection_recovery_fee  last_pymnt_d  loan_length   returns
# 2016565                      0.0      Sep-2017         31.0  0.826550
# 1397041                      0.0      Mar-2019         28.0  0.880710
# 1400045                      0.0      Mar-2019         28.0  0.895880
# 1956953                      0.0      Oct-2017         30.0  0.915269
# 2645214                      0.0           NaN        395.0  1.046262
#
# [5 rows x 116 columns]

# %% [markdown]
# The train/val/holdout split is designed to simulate future investments.
# Train and validate on historical data, and the (test)holdout set is the most recent loan data with full payment/chargoff information (3 years ago).

# %%
# split train and test data
test_end = pd.datetime(2016,9,1)
test_start = pd.datetime(2015,10,1)
test_df = df[(df['issue_d'] >= test_start) & (df['issue_d'] <= test_end)]

# %%
# verify start and end dates for test data
test_df.issue_d.min(), test_df.issue_d.max()
# Out:
# (Timestamp('2015-10-01 00:00:00'), Timestamp('2016-09-01 00:00:00'))

# %%
#export
train_end = pd.datetime(2015,9,1)
train_df = df[df['issue_d'] <= train_end]

# %%
# verify start and end dates for test data
train_df.issue_d.min(), train_df.issue_d.max()
# Out:
# (Timestamp('2007-06-01 00:00:00'), Timestamp('2015-09-01 00:00:00'))

# %% [markdown]
# Verify no test loans leak into train data. Testing intersection between sets much faster than finding overlap between lists of ids.

# %%
train_ids = set(train_df.id)
test_ids = set(test_df.id)

# %%
train_ids.intersection(test_ids)
# Out:
# set()

# %% [markdown]
# Check loan status within each data split.

# %%
train_df['loan_status'].value_counts()
# Out:
# Fully Paid     457060
# Charged Off     72813
# Current             2
# Name: loan_status, dtype: int64

# %%
train_df = train_df[(train_df['loan_status']=='Fully Paid')|(train_df['loan_status']=='Charged Off')]

# %%
train_df['loan_status'].value_counts()
# Out:
# Fully Paid     457060
# Charged Off     72813
# Name: loan_status, dtype: int64

# %%
test_df['loan_status'].value_counts()
# Out:
# Fully Paid            280747
# Charged Off            52415
# Current                   77
# Late (31-120 days)        77
# In Grace Period           11
# Late (16-30 days)          5
# Default                    2
# Name: loan_status, dtype: int64

# %%
# for simplicity
test_df = test_df[(test_df['loan_status']=='Fully Paid')|(test_df['loan_status']=='Charged Off')]

# %%
test_df['loan_status'].value_counts()
# Out:
# Fully Paid     280747
# Charged Off     52415
# Name: loan_status, dtype: int64

# %%
train_df['application_type'].value_counts()
# Out:
# Individual    529873
# Name: application_type, dtype: int64

# %%
test_df['application_type'].value_counts()
# Out:
# Individual    330206
# Joint App       2956
# Name: application_type, dtype: int64

# %%
test_df = test_df[test_df['application_type']!='Joint App']

# %%
test_df['application_type'].value_counts()
# Out:
# Individual    330206
# Name: application_type, dtype: int64

# %%
train_df.to_pickle('data/api_train_df.pkl')
test_df.to_pickle('data/api_test_df.pkl')
